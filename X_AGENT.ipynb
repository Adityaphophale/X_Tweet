# %% [markdown]
# <a href="https://colab.research.google.com/github/Adityaphophale/X_Tweet/blob/main/X_AGENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y google-generativeai
# !pip install -U google-generativeai
# Out:
# Found existing installation: google-generativeai 0.8.5
# Uninstalling google-generativeai-0.8.5:
#   Successfully uninstalled google-generativeai-0.8.5
# ...
#   Using cached google_generativeai-0.8.5-py3-none-any.whl.metadata (3.9 kB)
# ...
# Using cached google_generativeai-0.8.5-py3-none-any.whl (155 kB)
# ...

# %%
import google.generativeai as genai
from getpass import getpass

# %%
API_key = getpass("Enter your Google API Key: ")
genai.configure(api_key=API_key)
# Out:
# Enter your Google API Key: ··········

# %%
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
def tweet_generator(prompt_text):
    tweet_prompt = (
        f"You are a very talented social media assistant, write a tweet (250 characters text) "
        f"based on this prompt: {prompt_text}. "
        f"Keep it short, creative, and use hashtags."
    )

    response = model.generate_content(tweet_prompt)
    tweet = response.text.strip()
    return tweet
while True:
    prompt = input("Enter the prompt for tweet (type 'Exit' to quit): ")

    if prompt.lower() == "exit":
        print("Exiting...")
        break

    tweet = tweet_generator(prompt)
    print("Generated tweet is:", tweet, "\n")
# Out:
# Enter the prompt for tweet (type 'Exit' to quit): vadodara
# Generated tweet is: Vadodara: Where royal heritage meets vibrant modernity! Explore grand palaces, delicious food, and a rich cultural tapestry in Gujarat's heart. ❤️ #Vadodara #Gujarat #TravelIndia
#
# Enter the prompt for tweet (type 'Exit' to quit): exit
# Exiting...
